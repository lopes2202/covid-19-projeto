# %%
import pandas as pd

tabela = pd.read_csv("covid19_statistics.csv")

tabela = tabela.drop(columns="Unnamed")
tabela = tabela.drop(columns="date")
tabela = tabela.drop(columns="time_hms")

display(tabela)
# Out:
#          continent           country  cases.active  cases.critical  \
# 0             Asia             China      118977.0             NaN
# 1           Africa      Saint-Helena        2164.0             NaN
# 2    South-America  Falkland-Islands           0.0             NaN
# 3    North-America        Montserrat          19.0             NaN
# 4              NaN  Diamond-Princess           0.0             NaN
# ..             ...               ...           ...             ...
# 232  South-America     South-America     2149962.0          8953.0
# 233        Oceania           Oceania      110368.0            31.0
# 234         Africa            Africa      511224.0           529.0
# 235            All               All    22123398.0         34794.0
# 236  North-America               USA      786167.0           940.0
#
#      cases.recovered  cases.total  deaths.total  population(k)  test.total (k)
# 0           379053.0       503302        5272.0    1448471.400      160000.000
# ...

# %%
# Passo 3: Corrigir os problemas da base de dados (Tratamento de Dados)

display(tabela.info())
tabela = tabela.dropna()
display(tabela.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   continent        236 non-null    str
#  1   country          237 non-null    str
#  2   cases.active     190 non-null    float64
#  3   cases.critical   59 non-null     float64
#  4   cases.recovered  189 non-null    float64
#  5   cases.total      237 non-null    int64
#  6   deaths.total     232 non-null    float64
#  7   population(k)    229 non-null    float64
#  8   test.total (k)   213 non-null    float64
# dtypes: float64(6), int64(1), str(2)
# memory usage: 16.8 KB
# None
# <class 'pandas.DataFrame'>
# Index: 51 entries, 18 to 236
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   continent        51 non-null     str
#  1   country          51 non-null     str
# ...

# %%
contagem = tabela['continent'].value_counts()
print(contagem)

# contagem = tabela['continent'].value_counts(normalize=True)
# print(contagem)
# Out:
# continent
# Africa           13
# North-America    12
# Asia             10
# Europe            8
# South-America     7
# Oceania           1
# Name: count, dtype: int64

# %%
# Passo 5: Análise detalhada, taxa de porcentagem de pessoas que morreram em cada continente
import plotly.express as px

grafico = px.pie(tabela, names="continent", values="deaths.total", title=f"Proporção de Mortes por continente")
grafico.update_traces(textinfo='percent+label')
grafico.show()

# %%
# Taxa de letalidade em cada continente

tabela["letalidade"] = (tabela["deaths.total"] / tabela["cases.total"]) * 100 # criei outra label de letalidade

import plotly.express as px
grafico = px.bar(tabela, x="continent",  y="letalidade",  title="Taxa de Letalidade (%)",  color="letalidade") # letalidade nas cores

grafico.show()

# %%
grafico = px.pie(tabela, names="continent", values="population(k)", title=f"População por continente")
grafico.update_traces(textinfo='percent+label')
grafico.show()

# %%
grafico = px.pie(tabela, names="continent", values="cases.critical", title=f"Casos criticos por continente")
grafico.update_traces(textinfo='percent+label')
grafico.show()
